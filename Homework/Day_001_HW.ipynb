# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae
    
def mean_squared_error(y, yp):
    mse = MSE = sum(abs(y - yp) ** 2) / len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 291.919
# The Mean absolute error is 13.411

# %%
"""
作業2：
1. 你選的這組資料為何重要
 - New York City Airbnb Open Data : 
        Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present more unique, personalized way of experiencing the world. This dataset describes the listing activity and metrics in NYC, NY for 2019.
2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
 - This public dataset is part of Airbnb, and the original source can be found on this website.
3. 蒐集而來的資料型態為何
  - his data file includes all needed information to find out more about hosts, geographical availability, necessary metrics to make predictions and draw conclusions.
4. 這組資料想解決的問題如何評估
 - What can we learn about different hosts and areas?
 - What can we learn from predictions? (ex: locations, prices, reviews, etc)
 - Which hosts are the busiest and why?
 - Is there any noticeable difference of traffic among different areas and what could be the reason for it?
"""
# Out:
# '\n1. 你選的這組資料為何重要\n - New York City Airbnb Open Data : \n        Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present more unique, personalized way of experiencing the world. This dataset describes the listing activity and metrics in NYC, NY for 2019.\n2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)\n - This public dataset is part of Airbnb, and the original source can be found on this website.\n3. 蒐集而來的資料型態為何\n  - his data file includes all needed information to find out more about hosts, geographical availability, necessary metrics to make predictions and draw conclusions.\n4. 這組資料想解決的問題如何評估\n - What can we learn about different hosts and areas?\n - What can we learn from predictions? (ex: locations, prices, reviews, etc)\n - Which hosts are the busiest and why?\n - Is there any noticeable difference of traffic among different areas and what could be the reason for it?\n'

# %%
""""
作業3：申論題目可直接將答案回覆在HW檔案裡面，Jupyter notebook可直接編輯文字。
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
    - 需要什麼樣的數據才能得到讓業績提升的資料
2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
    - 車上的行程追蹤系統來獲取資料
3. 蒐集而來的資料型態為何
    - 包含區域載客量/客人搭乘的距離/搭車高峰期
4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
    - 每週/每月/每季 進行業績審核來評估資料的正確性並適時調整方向
"""
# Out:
# '"\n作業3：申論題目可直接將答案回覆在HW檔案裡面，Jupyter notebook可直接編輯文字。\n想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：\n1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)\n    - 需要什麼樣的數據才能得到讓業績提升的資料\n2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)\n    - 車上的行程追蹤系統來獲取資料\n3. 蒐集而來的資料型態為何\n    - 包含區域載客量/客人搭乘的距離/搭車高峰期\n4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)\n    - 每週/每月/每季 進行業績審核來評估資料的正確性並適時調整方向\n'
